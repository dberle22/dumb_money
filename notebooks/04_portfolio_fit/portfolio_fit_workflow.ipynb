# %% [markdown]
# # Portfolio Fit Workflow
#
# This notebook is the thin review layer for Sprint 7. It is intentionally built on shared modules rather than notebook-only portfolio logic.

# %%
from dumb_money.research import build_portfolio_summary, build_watchlist_summary

# %%
summary = build_portfolio_summary(portfolio_id="default", candidate_ticker="AAPL")
summary["concentration_metrics"]

# %%
summary["sector_exposure"]

# %%
summary["benchmark_comparison"]

# %%
build_watchlist_summary(["AAPL", "MSFT", "NVDA"], portfolio_id="default")
